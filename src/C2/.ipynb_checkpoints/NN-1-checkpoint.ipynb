# %% [markdown]
# # Demo : No pattern found
#
# Author: Jim Xie
#
# Date:   2020-08-07

# %%
# -*- coding: utf-8 -*- 
import sys,os,logging,time,json,cv2,json,threading,uuid,logging,cv2,datetime
import numpy as np
import random
from matplotlib import pyplot as plt
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# %matplotlib inline
import pandas as pd
import seaborn as sns
from sklearn import preprocessing
import math
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from numpy.random import RandomState
np.set_printoptions(suppress=True)
from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From /Users/jim/anaconda3/envs/p36/lib/python3.6/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def GetParityData():
    dataset_size = 100
    x1 = np.random.random_integers(1,100,dataset_size )
    x2 = np.random.random_integers(1,100,dataset_size )
    y = []
    x = []
    for t1,t2 in zip(x1,x2):
        x.append([t1,t2])
        if (t1+t2)%2 == 0:
            y.append([1])
        else:
            y.append([0])
    return np.array(x),np.array(y)

# %%
def GetMulData():
    dataset_size = 100
    x = RandomState(1).rand(dataset_size,2)
    y = []
    for t1,t2 in x:
        if (t1*t2) > 0.25:
            y.append([1])
        else:
            y.append([0])
    return np.array(x),np.array(y)

# %%
def GenerateData():
    x,y = GetMulData()
    #x = preprocessing.scale(x)
    return x,y

# %%
raw_x,raw_y = GenerateData()

# %%
df = pd.DataFrame(raw_x)
df['label'] = raw_y
plt.style.use({'figure.figsize':(12, 6)})
sns.set(font_scale=1)
ax = sns.scatterplot(x=0, y=1, data=df,hue='label',s=300)
ax.ticklabel_format(style='plain',axis='both')
plt.xlabel('x1',fontsize=24)
plt.ylabel('x2',fontsize=24)
# Out:
# Text(0, 0.5, 'x2')

# %%
input_x = tf.placeholder(tf.float32, [None, 2])
input_y = tf.placeholder(tf.float32, [None, 1])

# %%
def Create_Input(n_hidden_count):
    dim = input_x.shape[1].value
    w = tf.Variable(tf.random_normal([dim,n_hidden_count],stddev=1,seed=1))
    b = tf.Variable(tf.random_normal([n_hidden_count],stddev=1,seed=1))
    o = tf.matmul(input_x, w)+b
    #o = tf.nn.sigmoid(o)
    o = tf.nn.tanh(o)
    return o

# %%
def Create_Hidden(in_data,n_hidden_count):
    dim = in_data.shape[1].value
    w = tf.Variable( tf.truncated_normal([dim, n_hidden_count]), name = 'w')
    b = tf.Variable(tf.random_normal([n_hidden_count],stddev=1,seed=1))
    o = tf.matmul(in_data, w)+b
    #o = tf.nn.sigmoid(o)
    o = tf.nn.tanh(o)
    return o

# %%
def Create_Output(in_data):
    dim = in_data.shape[1].value
    out_dim = input_y.shape[1].value
    w = tf.Variable( tf.truncated_normal([dim, out_dim]), name = 'w')
    b = tf.Variable(tf.random_normal([out_dim],stddev=1,seed=1))
    o = tf.matmul(in_data, w)+b
    return o

# %%
L0 = Create_Input(5)
L1 = Create_Hidden(L0,10)
prediction = Create_Output(L1)

# %%
entropy = input_y * tf.log(tf.clip_by_value(prediction,1e-10,1.0))+(1-input_y) * tf.log(tf.clip_by_value(1-prediction,1e-10,1.0))
cross_entropy = -tf.reduce_mean(entropy)

train_step = tf.train.AdamOptimizer(0.01).minimize(entropy)
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
for i in range(500):
    sess.run(train_step,feed_dict={input_x:raw_x,input_y:raw_y})
    if i % 100 == 0:
        total_cross_entropy = sess.run(cross_entropy,feed_dict={input_x:raw_x,input_y:raw_y})
        print("Step %d, loss is %g"%(i,total_cross_entropy))
# Out:
# Step 0, loss is 8.98008
# Step 100, loss is 8.98008
# Step 200, loss is 8.98008
# Step 300, loss is 8.98008
# Step 400, loss is 8.98008

# %%
test_x,test_y = GenerateData()
pred_Y = sess.run(prediction,feed_dict={input_x:test_x})
pred_Y[(pred_Y>= 0.5)] = 1
pred_Y[(pred_Y< 0.5)] = 0

# %%
test_y = np.squeeze(test_y)
pred_Y = np.squeeze(pred_Y)
test_label = []
for x,t1,t2 in zip(test_x,test_y,pred_Y):
    if t1 == t2:
        test_label.append('True')
    else:
        test_label.append('False')
    print("(%f) %f-->%f"%((x[0]+x[1]),t1,t2))
# Out:
# (1.137346) 1.000000-->0.000000
# (0.302447) 0.000000-->0.000000
# (0.239094) 0.000000-->0.000000
# (0.531821) 0.000000-->0.000000
# (0.935584) 0.000000-->0.000000
# (1.104414) 1.000000-->0.000000
# (1.082570) 0.000000-->0.000000
# (0.697855) 0.000000-->0.000000
# (0.975995) 0.000000-->0.000000
# (0.338488) 0.000000-->0.000000
# (1.769006) 1.000000-->0.000000
# (1.005747) 0.000000-->0.000000
# (1.770996) 1.000000-->0.000000
# (0.124099) 0.000000-->0.000000
# (1.047973) 0.000000-->0.000000
# (0.519454) 0.000000-->0.000000
# (1.491055) 1.000000-->0.000000
# (1.007393) 0.000000-->0.000000
# (1.521127) 1.000000-->0.000000
# (0.768433) 0.000000-->0.000000
# (1.737027) 1.000000-->0.000000
# (1.069723) 0.000000-->0.000000
# (0.551120) 0.000000-->0.000000
# (1.202210) 1.000000-->0.000000
# (0.417804) 0.000000-->0.000000
# (0.698202) 0.000000-->0.000000
# (0.477175) 0.000000-->0.000000
# (0.544936) 0.000000-->0.000000
# (0.720846) 0.000000-->0.000000
# (1.289064) 1.000000-->0.000000
# (0.516390) 0.000000-->0.000000
# (1.108579) 1.000000-->0.000000
# (0.585850) 0.000000-->0.000000
# (1.178684) 1.000000-->0.000000
# (1.531150) 1.000000-->0.000000
# (1.040877) 0.000000-->0.000000
# (0.946668) 0.000000-->0.000000
# (0.563031) 0.000000-->0.000000
# (1.275274) 1.000000-->0.000000
# (1.476810) 1.000000-->0.000000
# (1.506978) 1.000000-->0.000000
# (1.099841) 1.000000-->0.000000
# (1.165814) 0.000000-->0.000000
# (1.392931) 1.000000-->0.000000
# (1.285137) 1.000000-->0.000000
# (1.064235) 0.000000-->0.000000
# (1.028302) 1.000000-->0.000000
# (0.645164) 0.000000-->0.000000
# (1.477059) 1.000000-->0.000000
# (0.620015) 0.000000-->0.000000
# (0.853703) 0.000000-->0.000000
# (1.243212) 1.000000-->0.000000
# (1.531895) 1.000000-->0.000000
# (0.945258) 0.000000-->0.000000
# (1.688220) 1.000000-->0.000000
# (0.309476) 0.000000-->0.000000
# (1.629414) 1.000000-->0.000000
# (0.821463) 0.000000-->0.000000
# (1.676901) 1.000000-->0.000000
# (0.835796) 0.000000-->0.000000
# (0.046091) 0.000000-->0.000000
# (0.274518) 0.000000-->0.000000
# (1.398859) 1.000000-->0.000000
# (1.394853) 1.000000-->0.000000
# (0.403357) 0.000000-->0.000000
# (1.555355) 1.000000-->0.000000
# (0.579678) 0.000000-->0.000000
# (1.033607) 0.000000-->0.000000
# (1.194966) 1.000000-->0.000000
# (1.610663) 1.000000-->0.000000
# (0.692695) 0.000000-->0.000000
# (0.181261) 0.000000-->0.000000
# (0.152046) 0.000000-->0.000000
# (0.938698) 0.000000-->0.000000
# (0.572273) 0.000000-->0.000000
# (1.039251) 0.000000-->0.000000
# (0.771394) 0.000000-->0.000000
# (0.996152) 0.000000-->0.000000
# (0.776788) 0.000000-->0.000000
# (1.816849) 1.000000-->0.000000
# (0.733617) 0.000000-->0.000000
# (1.448937) 1.000000-->0.000000
# (0.175368) 0.000000-->0.000000
# (0.556367) 0.000000-->0.000000
# (1.175181) 1.000000-->0.000000
# (1.305979) 1.000000-->0.000000
# (0.959886) 0.000000-->0.000000
# (1.296283) 1.000000-->0.000000
# (0.934152) 0.000000-->0.000000
# (0.436419) 0.000000-->0.000000
# (0.839892) 0.000000-->0.000000
# (0.819292) 0.000000-->0.000000
# (1.065070) 0.000000-->0.000000
# (0.832895) 0.000000-->0.000000
# (1.449478) 1.000000-->0.000000
# (0.329258) 0.000000-->0.000000
# (1.507244) 1.000000-->0.000000
# (1.839788) 1.000000-->0.000000
# (0.248314) 0.000000-->0.000000
# (1.565795) 1.000000-->0.000000

# %%
df1 = pd.DataFrame(raw_x)
df1['label'] = test_label
plt.style.use({'figure.figsize':(12, 6)})
sns.set(font_scale=1)
ax = sns.scatterplot(x=0, y=1, data=df1,hue='label')
ax.ticklabel_format(style='plain',axis='both')
plt.xlabel('x1',fontsize=24)
plt.ylabel('x2',fontsize=24)
# Out:
# Text(0, 0.5, 'x2')

# %%
conf = tf.confusion_matrix(labels=test_y, predictions=pred_Y,num_classes=2)
conf_numpy = conf.eval(session=sess)
conf_df = pd.DataFrame(conf_numpy) 
print(conf_numpy)
# Out:
# [[61  0]
#  [39  0]]
