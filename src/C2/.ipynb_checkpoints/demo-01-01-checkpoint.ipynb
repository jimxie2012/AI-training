# %% [markdown]
# EDA
# 年龄分布探索

# %%
import sys
#!{sys.executable} -m pip install seaborn==0.9.0
import seaborn
print(seaborn.__version__)
import random
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
#sns.set(rc={"figure.figsize": (24, 12)})
plt.style.use({'figure.figsize':(24, 12)})
sns.set_style('dark')
sns.set_context("poster")
#sns.set(font_scale=5)
# Out:
# 0.9.0

# %%
df = pd.read_csv('./COVID19/AgeGroupDetails.csv')
df['Percentage'] = df['Percentage'].str.replace('%','',regex=False).astype(float)

# %%
df.head(10)
# Out:
#    Sno AgeGroup  TotalCases  Percentage
# 0    1      0-9          22        3.18
# 1    2    10-19          27        3.90
# 2    3    20-29         172       24.86
# 3    4    30-39         146       21.10
# 4    5    40-49         112       16.18
# 5    6    50-59          77       11.13
# 6    7    60-69          89       12.86
# 7    8    70-79          28        4.05
# 8    9     >=80          10        1.45
# 9   10  Missing           9        1.30

# %%
df.shape
# Out:
# (10, 4)

# %%
df.isnull().sum()
# Out:
# Sno           0
# AgeGroup      0
# TotalCases    0
# Percentage    0
# dtype: int64

# %%
df.dtypes
# Out:
# Sno             int64
# AgeGroup       object
# TotalCases      int64
# Percentage    float64
# dtype: object

# %%
df.describe(include='all')
# Out:
#              Sno AgeGroup  TotalCases  Percentage
# count   10.00000       10   10.000000   10.000000
# unique       NaN       10         NaN         NaN
# top          NaN    10-19         NaN         NaN
# freq         NaN        1         NaN         NaN
# mean     5.50000      NaN   69.200000   10.001000
# std      3.02765      NaN   59.241127    8.560866
# min      1.00000      NaN    9.000000    1.300000
# 25%      3.25000      NaN   23.250000    3.360000
# 50%      5.50000      NaN   52.500000    7.590000
# 75%      7.75000      NaN  106.250000   15.350000
# max     10.00000      NaN  172.000000   24.860000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
# Sno           10 non-null int64
# AgeGroup      10 non-null object
# TotalCases    10 non-null int64
# Percentage    10 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 400.0+ bytes

# %%
df['AgeGroup'].unique()
# Out:
# array(['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69',
#        '70-79', '>=80', 'Missing'], dtype=object)

# %%
sns.barplot(x="AgeGroup", y="Percentage", data=df)

# %%
sns.scatterplot(x="AgeGroup", y="TotalCases", data=df)

# %%
sns.lineplot(x='AgeGroup', y='TotalCases', markers=True, data=df)
plt.grid(linestyle=':')
plt.show()
